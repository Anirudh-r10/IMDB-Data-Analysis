# %% [markdown]
# ### Name:ANIRUDH SHENOY ,BATCH:DST 20823

# %% [markdown]
# ## Explanation :
# This Database Contains Movies Created By Several Directors In The World.
#
# This Database Can Be Seen At: https://www.kaggle.com/luizpaulodeoliveira/imdb-project-sql
#
# This Database Contains Two Tables. The First Table Is Called 'directors', Contains The Name Of The Director And His Gender. The Second Table Is Called 'movies', Contains The Title Of The Movies, budget, revenue, popularity, etc.
#
# From This database, You Can Find Out The Best Movies Based On Income, Popularity And Votes. In Addition, You Can Also Find Out The Best Director Based On The Amount Of Revenue From All His Movies.
#
# The Correlation Coefficient Of These Two Tables Can Show The Effect Of Each Column To The Other Column.
#
# --> Analysis on IMDB useful libraries with sql
# ### Explanation
# __SQLite__ : - SQLite database is integrated with the application that accesses the database. The applications interact with the SQLite database read and write directly from the database files stored on disk.
#
# SQLite does NOT require a server to run.
#
# Refer at https://www.sqlite.org/index.html
#
# __PANDAS__ : - Pandas provide high performance, fast, easy to use data structures and data analysis tools for manipulating numeric data and time series. Pandas is built on the numpy library and written in languages like Python, Cython, and C. In pandas, we can import data from various file formats like JSON, SQL, Microsoft Excel, etc.
#
# __NUMPY__: - Numpy is an Python library,It is used for scientific computing in python.It contains a collection of tools and techniques that can be used to solve on computers with mathematical model of problems. - High performance and multi-dimensional areay objects. - High level mathematical functions. - matrices

# %%
# Import Pandas and NumPy

import numpy as np
import pandas as pd

#pip install db-sqlite3
#SQLite in general is a server-less database that you can use within almost all programming languages including Python.
import sqlite3

# %% [markdown]
# We import the sqlite3 module and then create a connection object which will connect us to the database and will let us execute the SQL statements.
#
# sqlite3.connect(Database)
#
# __cursor()__ - we can use the cursor object to call the execute() method to execute any SQL queries.
#
# __STEPS:__
# To query data in an SQLite database from Python, you use these steps:
#
# - First, establish a connection to the SQLite database by creating a Connection object.
# - Next, create a Cursor object using the cursor method of the Connection object.
# - Then, execute a SELECT statement.
# - After that, call the fetchall() method of the cursor object to fetch the data.
# - Finally, loop the cursor and process each row individually.

# %%
db = 'movies.sqlite'


conn = sqlite3.connect(db)
cur = conn.cursor()

# %% [markdown]
# ## QUESTIONS
# ### Question 1: Can you get all data about movies?

# %%
cur.execute('SELECT * FROM movies')
#use the cursor object to call the execute() method to execute any SQL queries.
movies = cur.fetchall()

#movies -> if u print movies , all the data shown in list manner, can't understanadble

#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.

movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.



print('Shape of Movies data :',movies.shape)
print('\n\n\n')
movies.head()

#Displays first 3 rows in the table
# Out:
# Shape of Movies data : (4773, 13)
#       id                            original_title     budget  popularity  \
# 0  43597                                    Avatar  237000000         150
# 1  43598  Pirates of the Caribbean: At World's End  300000000         139
# 2  43599                                   Spectre  245000000         107
# 3  43600                     The Dark Knight Rises  250000000         112
# 4  43601                               John Carter  260000000          43
#
#   release_date     revenue                                     title  \
# 0   2009-12-10  2787965087                                    Avatar
# 1   2007-05-19   961000000  Pirates of the Caribbean: At World's End
# 2   2015-10-26   880674609                                   Spectre
# 3   2012-07-16  1084939099                     The Dark Knight Rises
# 4   2012-03-07   284139100                               John Carter
#
#    vote_average  vote_count  \
# 0           7.2       11800
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4773 entries, 0 to 4772
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4773 non-null   int64
#  1   original_title  4773 non-null   object
#  2   budget          4773 non-null   int64
#  3   popularity      4773 non-null   int64
#  4   release_date    4773 non-null   object
#  5   revenue         4773 non-null   int64
#  6   title           4773 non-null   object
#  7   vote_average    4773 non-null   float64
#  8   vote_count      4773 non-null   int64
#  9   overview        4770 non-null   object
#  10  tagline         3951 non-null   object
#  11  uid             4773 non-null   int64
#  12  director_id     4773 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 484.9+ KB

# %% [markdown]
# ## Question 2: How do you get all data about directors?

# %%
cur.execute('SELECT * FROM directors')
#use the cursor object to call the execute() method to execute any SQL queries.

directors = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.


directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.

print('Shape of Directors data :',directors.shape)
print('\n\n\n')


directors.head(100)
# Out:
# Shape of Directors data : (2349, 5)
#                  name    id  gender     uid department
# 0       James Cameron  4762       2    2710  Directing
# 1      Gore Verbinski  4763       2    1704  Directing
# 2          Sam Mendes  4764       2      39  Directing
# 3   Christopher Nolan  4765       2     525  Directing
# 4      Andrew Stanton  4766       2       7  Directing
# ..                ...   ...     ...     ...        ...
# 95         Joe Wright  4857       2   36588  Directing
# 96        Rob Minkoff  4858       2   18898  Directing
# 97       Lee Tamahori  4859       2    7256  Directing
# 98          Paul Feig  4860       2  116805  Directing
# 99       Peter Ramsey  4861       2  151007  Directing
#
# [100 rows x 5 columns]

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2349 non-null   object
#  1   id          2349 non-null   int64
#  2   gender      2349 non-null   int64
#  3   uid         2349 non-null   int64
#  4   department  2349 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 91.9+ KB

# %% [markdown]
# ## Question 3: Check how many movies are present in iMDB.

# %%
#cur.execute('SELECT * FROM directors')
#use the cursor object to call the execute() method to execute any SQL queries.

#directors = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.


#directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.



cur.execute(' SELECT COUNT(*) FROM MOVIES ')
count_movies=cur.fetchone()[0] # fetchone used to fetch the result as single value count
print(f"The number of movies present in IMDB are:{count_movies}")

cur.execute('SELECT * FROM MOVIES')
movie=cur.fetchall()
movie=pd.DataFrame(movies,columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])

print('Shape of Movies data :',movie.shape)
print('\n\n\n')



movie
# Out:
# The number of movies present in IMDB are:4773
# Shape of Movies data : (4773, 13)
#          id                            original_title     budget  popularity  \
# 0     43597                                    Avatar  237000000         150
# 1     43598  Pirates of the Caribbean: At World's End  300000000         139
# 2     43599                                   Spectre  245000000         107
# 3     43600                     The Dark Knight Rises  250000000         112
# 4     43601                               John Carter  260000000          43
# ...     ...                                       ...        ...         ...
# 4768  48395                               El Mariachi     220000          14
# 4769  48396                                 Newlyweds       9000           0
# 4770  48397                 Signed, Sealed, Delivered          0           1
# 4771  48398                          Shanghai Calling          0           0
# ...

# %% [markdown]
# ## Question 4: Find these 3 directors: James Cameron ; Luc Besson ; John Woo

# %%
cur.execute("SELECT * FROM directors WHERE name IN ('James Cameron', 'Luc Besson', 'John Woo')")
directors = cur.fetchall()



directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
directors
# Out:
#             name    id  gender    uid department
# 0  James Cameron  4762       2   2710  Directing
# 1       John Woo  4893       2  11401  Directing
# 2     Luc Besson  4949       2     59  Directing

# %% [markdown]
# ## Question 5: Find all directors with name starting with Steven.

# %%
cur.execute("SELECT * FROM directors WHERE name LIKE 'Steven%' ")
steven = cur.fetchall()
steven = pd.DataFrame(steven, columns = ['name', 'id', 'gender', 'uid', 'department'])

steven
# Out:
#                  name    id  gender    uid department
# 0    Steven Spielberg  4799       2    488  Directing
# 1   Steven Soderbergh  4909       2   1884  Directing
# 2        Steven Brill  5013       2  32593  Directing
# 3     Steven Zaillian  5117       2   2260  Directing
# 4        Steven Quale  5216       2  93214  Directing
# 5       Steven Seagal  5221       2  23880  Directing
# 6  Steven E. de Souza  5390       2   1726  Directing
# 7    Steven Shainberg  5803       2  67795  Directing
# 8    Steven R. Monroe  6713       2  88039  Directing

# %% [markdown]
# ## Question 6: Count female directors.

# %%
cur.execute("SELECT COUNT(*) FROM directors WHERE gender=1 ")
count_female_dir = cur.fetchone()[0]
print(f"The number of Female directors present in IMDB are:{count_female_dir}")
print("\n\n")

print("The female directors are: \n")
cur.execute("SELECT * FROM directors WHERE gender=1 ")
female_dir = cur.fetchall()
female_dir = pd.DataFrame(female_dir, columns = ['name', 'id', 'gender', 'uid', 'department'])

female_dir.head(100)
# Out:
# The number of Female directors present in IMDB are:150
#
#
#
# The female directors are:
#                    name    id  gender     uid department
# 0        Brenda Chapman  4801       1   59803  Directing
# 1       Lilly Wachowski  4805       1    9339  Directing
# 2   Jennifer Yuh Nelson  4853       1  142312  Directing
# 3       Kathryn Bigelow  4970       1   14392  Directing
# 4          Nancy Meyers  4978       1   17698  Directing
# ..                  ...   ...     ...     ...        ...
# 95        Caroline Link  6284       1    4522  Directing
# 96   Risa Bramon Garcia  6301       1    3191  Directing
# 97            Deb Hagan  6306       1   77911  Directing
# 98    Joey Lauren Adams  6318       1   16484  Directing
# 99          Liv Ullmann  6349       1   11916  Directing
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Question 7: Find the name of the 10th first women directors?

# %%
cur.execute('SELECT name FROM directors WHERE gender == 1 ORDER BY id LIMIT 1 OFFSET 10 ')
ten_women=cur.fetchone()[0]
print(f"The name of the 10th first women director is:{ten_women}")
print("\n")



cur.execute('SELECT * FROM directors WHERE gender == 1 ORDER BY id ')
women=cur.fetchall()

women=pd.DataFrame(women, columns = ['Director name', 'id', 'gender', 'uid', 'department'])
women.head(11)
# Out:
# The name of the 10th first women director is:Karyn Kusama
#           Director name    id  gender     uid department
# 0        Brenda Chapman  4801       1   59803  Directing
# 1       Lilly Wachowski  4805       1    9339  Directing
# 2   Jennifer Yuh Nelson  4853       1  142312  Directing
# 3       Kathryn Bigelow  4970       1   14392  Directing
# 4          Nancy Meyers  4978       1   17698  Directing
# 5           Jill Culton  4979       1    7881  Directing
# 6            Mimi Leder  4996       1   51984  Directing
# 7          Vicky Jenson  5032       1   12058  Directing
# 8          Betty Thomas  5052       1   31024  Directing
# 9        Angelina Jolie  5086       1   11701  Directing
# 10         Karyn Kusama  5174       1   54025  Directing

# %% [markdown]
# ## Question 8: What are the 3 most popular movies?

# %%
cur.execute('SELECT original_title FROM movies ORDER BY popularity desc LIMIT 3 ')
original_title=cur.fetchall()
print(f"The 3 most popular movies are: ")
for title in original_title:
    print(title[0])
print("\n")

cur.execute('SELECT * FROM movies ORDER BY popularity desc LIMIT 3 ')
pop_movie=cur.fetchall()
pop_movie=pd.DataFrame(pop_movie,columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
pop_movie
# Out:
# The 3 most popular movies are:
# Minions
# Interstellar
# Deadpool
#       id original_title     budget  popularity release_date     revenue  \
# 0  44143        Minions   74000000         875   2015-06-17  1156730962
# 1  43692   Interstellar  165000000         724   2014-11-05   675120017
# 2  44385       Deadpool   58000000         514   2016-02-09   783112979
#
#           title  vote_average  vote_count  \
# 0       Minions           6.4        4571
# 1  Interstellar           8.1       10867
# 2      Deadpool           7.4       10995
#
#                                             overview  \
# 0  Minions Stuart, Kevin and Bob are recruited by...
# 1  Interstellar chronicles the adventures of a gr...
# 2  Deadpool tells the origin story of former Spec...
#
#                                              tagline     uid  director_id
# 0       Before Gru, they had a history of bad bosses  211672         5045
# ...

# %% [markdown]
# ## Question 9: What are the 3 most bankable movies?

# %%
cur.execute('SELECT original_title FROM movies ORDER BY revenue desc LIMIT 3 ')
bank_movie=cur.fetchall()
print("The 3 most bankable movies are:")
for m in bank_movie:
    print(m[0])
print("\n")


cur.execute('SELECT * FROM movies ORDER BY revenue desc LIMIT 3 ')
bank_movie=cur.fetchall()
bank_movie=pd.DataFrame(bank_movie,columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
bank_movie
# Out:
# The 3 most bankable movies are:
# Avatar
# Titanic
# The Avengers
#       id original_title     budget  popularity release_date     revenue  \
# 0  43597         Avatar  237000000         150   2009-12-10  2787965087
# 1  43622        Titanic  200000000         100   1997-11-18  1845034188
# 2  43613   The Avengers  220000000         144   2012-04-25  1519557910
#
#           title  vote_average  vote_count  \
# 0        Avatar           7.2       11800
# 1       Titanic           7.5        7562
# 2  The Avengers           7.4       11776
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  84 years later, a 101-year-old woman named Ros...
# 2  When an unexpected enemy emerges and threatens...
#
#                                      tagline    uid  director_id
# 0                Enter the World of Pandora.  19995         4762
# 1  Nothing on Earth could come between them.    597         4762
# ...

# %% [markdown]
# ## Question 10: What is the most awarded average vote since the January 1st, 2000?

# %%
cur.execute('SELECT MAX(vote_average) as Max_Average FROM movies WHERE release_date >= "2000-01-01"')
max_avg=cur.fetchone()[0]
print(" The most awarded average vote since the January 1st, 2000 is: ",max_avg)
print("\n")

print("The details are:")
cur.execute('SELECT * FROM movies WHERE vote_average = ?', (max_avg,))
max_av=cur.fetchall()
max_av=pd.DataFrame(max_av,columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
max_av
# Out:
#  The most awarded average vote since the January 1st, 2000 is:  9.5
#
#
# The details are:
#       id original_title  budget  popularity release_date  revenue      title  \
# 0  47589      Sardaarji       0           0   2015-06-26        0  Sardaarji
#
#    vote_average  vote_count  \
# 0           9.5           2
#
#                                             overview tagline     uid  \
# 0  A ghost hunter uses bottles to capture trouble...    None  346081
#
#    director_id
# 0         6588

# %% [markdown]
# ## Question 11: Which movie(s) were directed by Brenda Chapman?

# %%
cur.execute('SELECT m.original_title,d.name FROM movies as m JOIN directors as d ON m.director_id = d.id WHERE name == "Brenda Chapman"')
brenda=cur.fetchall()
brenda=pd.DataFrame(brenda,columns = ['Original_title','Director Name'])
brenda
# Out:
#   Original_title   Director Name
# 0          Brave  Brenda Chapman

# %% [markdown]
# ## Question 12: Whose director made the most movies?

# %%
cur.execute('SELECT d.name, COUNT(m.director_id) as count FROM directors as d JOIN movies as m ON d.id = m.director_id GROUP BY d.name ORDER BY count DESC LIMIT 1')
most=cur.fetchall()
most=pd.DataFrame(most,columns = ['Director name','count'])
most
# Out:
#       Director name  count
# 0  Steven Spielberg     27

# %% [markdown]
# ## Question 13: Whose director is the most bankable?

# %%
cur.execute('SELECT d.name,SUM(m.revenue) as Revenue from directors as d JOIN movies as m ON d.id=m.director_id GROUP BY d.name ORDER BY Revenue DESC LIMIT 1')
dir=cur.fetchall()
dir=pd.DataFrame(dir,columns = ['Director name','Revenue'])
dir
# Out:
#       Director name     Revenue
# 0  Steven Spielberg  9147393164

# %% [markdown]
# ## Budget Analysis  - List out Top 10 highest budget made movies

# %%
cur.execute('SELECT * FROM movies ORDER BY budget DESC LIMIT 10')
budget=cur.fetchall()
budget=pd.DataFrame(budget,columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
budget
# Out:
#       id                               original_title     budget  popularity  \
# 0  43614  Pirates of the Caribbean: On Stranger Tides  380000000         135
# 1  43598     Pirates of the Caribbean: At World's End  300000000         139
# 2  43604                      Avengers: Age of Ultron  280000000         134
# 3  43607                             Superman Returns  270000000          57
# 4  43601                                  John Carter  260000000          43
# 5  43603                                      Tangled  260000000          48
# 6  43602                                 Spider-Man 3  258000000         115
# 7  43610                              The Lone Ranger  255000000          49
# 8  43600                        The Dark Knight Rises  250000000         112
# 9  43605       Harry Potter and the Half-Blood Prince  250000000          98
#
#   release_date     revenue                                        title  \
# ...

# %% [markdown]
# ## Popularity Analysis
# # Question- List out Top 10 popularity on movies

# %%
cur.execute('SELECT * FROM movies ORDER BY popularity DESC LIMIT 10')
pop=cur.fetchall()
pop=pd.DataFrame(pop,columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
pop
# Out:
#       id                                     original_title     budget  \
# 0  44143                                            Minions   74000000
# 1  43692                                       Interstellar  165000000
# 2  44385                                           Deadpool   58000000
# 3  43691                            Guardians of the Galaxy  170000000
# 4  43724                                 Mad Max: Fury Road  150000000
# 5  43625                                     Jurassic World  150000000
# 6  43796  Pirates of the Caribbean: The Curse of the Bla...  140000000
# 7  43679                     Dawn of the Planet of the Apes  170000000
# 8  43797              The Hunger Games: Mockingjay - Part 1  125000000
# 9  43685                                         Big Hero 6  165000000
#
#    popularity release_date     revenue  \
# 0         875   2015-06-17  1156730962
# 1         724   2014-11-05   675120017
# 2         514   2016-02-09   783112979
# ...

# %% [markdown]
# ## Revenue Analysis
# # Question - What are the top 10 Revenue movies

# %%
cur.execute('SELECT * FROM movies ORDER BY revenue DESC LIMIT 10')
rev=cur.fetchall()
rev=pd.DataFrame(rev,columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
rev
# Out:
#       id              original_title     budget  popularity release_date  \
# 0  43597                      Avatar  237000000         150   2009-12-10
# 1  43622                     Titanic  200000000         100   1997-11-18
# 2  43613                The Avengers  220000000         144   2012-04-25
# 3  43625              Jurassic World  150000000         418   2015-06-09
# 4  43641                   Furious 7  190000000         102   2015-04-01
# 5  43604     Avengers: Age of Ultron  280000000         134   2015-04-22
# 6  43721                      Frozen  150000000         165   2013-11-27
# 7  43628                  Iron Man 3  200000000          77   2013-04-18
# 8  44143                     Minions   74000000         875   2015-06-17
# 9  43623  Captain America: Civil War  250000000         198   2016-04-27
#
#       revenue                       title  vote_average  vote_count  \
# 0  2787965087                      Avatar           7.2       11800
# ...

# %% [markdown]
# ## Voting Analysis
# # Question - Display most popular movies with vote_average

# %%
print("The most popular movies with respect to vote Average are:")
print("\n\n")

cur.execute('SELECT * FROM movies ORDER BY vote_average desc ')
pop=cur.fetchall()
pop=pd.DataFrame(pop,columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
pop.head(100)
# Out:
# The most popular movies with respect to vote Average are:
#        id                         original_title    budget  popularity  \
# 0   47116                       Stiff Upper Lips         0           0
# 1   47642                  Dancer, Texas Pop. 81         0           0
# 2   47589                              Sardaarji         0           0
# 3   45983                         One Man's Hero         0           0
# 4   45478               The Shawshank Redemption  25000000         136
# ..    ...                                    ...       ...         ...
# 95  45749  Eternal Sunshine of the Spotless Mind  20000000          56
# 96  46113                        American Beauty  15000000          80
# 97  46457                               Das Boot  14000000          26
# 98  46563                  2001: A Space Odyssey  10500000          86
# 99  46572                      Good Will Hunting  10000000          43
#
# ...

# %% [markdown]
# # Question - List out Particular movie for Voting average and votecount

# %%
cur.execute("SELECT original_title, vote_average, vote_count FROM movies ORDER BY vote_average desc,vote_count desc")

vot=cur.fetchall()

vot=pd.DataFrame(vot,columns = ['Original Title','Vote Average','Vote Count'])
vot.head(10)
# Out:
#              Original Title  Vote Average  Vote Count
# 0          Stiff Upper Lips          10.0           1
# 1     Dancer, Texas Pop. 81          10.0           1
# 2                 Sardaarji           9.5           2
# 3            One Man's Hero           9.3           2
# 4  The Shawshank Redemption           8.5        8205
# 5        There Goes My Baby           8.5           2
# 6             The Godfather           8.4        5893
# 7     The Prisoner of Zenda           8.4          11
# 8                Fight Club           8.3        9413
# 9              Pulp Fiction           8.3        8428

# %% [markdown]
# ## Directors Analysis
# # Question- List out the director names with number of movies and revenue

# %%
cur.execute('SELECT d.name, COUNT(m.director_id) as count, SUM(m.revenue) as revenue  FROM directors as d JOIN movies as m ON d.id = m.director_id GROUP BY d.name ORDER BY count desc')
dir=cur.fetchall()
dir=pd.DataFrame(dir,columns = ['Director Name','Count','Revnue'])
dir
# Out:
#          Director Name  Count      Revnue
# 0     Steven Spielberg     27  9147393164
# 1          Woody Allen     21   669101038
# 2      Martin Scorsese     20  1956635998
# 3       Clint Eastwood     20  2512058888
# 4            Spike Lee     16   340618771
# ...                ...    ...         ...
# 2344      Adam Carolla      1           0
# 2345       Adam Brooks      1    55447968
# 2346      Abel Ferrara      1     1227324
# 2347   Aaron Schneider      1           0
# 2348        Aaron Hann      1           0
#
# [2349 rows x 3 columns]
